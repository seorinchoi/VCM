# %%
# %cd ..
# Out:
# /home/modan9012/mmsegmentation

# %%
# Pytorch 설치 확인
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

import mmcv
print(mmcv.__version__)

# MMSegmentation 설치 확인
import mmseg
print(mmseg.__version__)
# Out:
# 1.12.0+cu116 True
# 2.1.0
# 1.2.2

# %%
import os.path as osp
import numpy as np
from PIL import Image
import mmcv
import mmengine
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os

# %%
# dataset root와 이미지, annotation이 위치할 디렉토리 정의
data_root = './datasets/test-small/'
img_dir = 'images'
mask_dir = 'masks'
# 각 클래스에 대한 팔레트(색상)을 정의
classes = ('background', 'kidney')
palette = [[128,0,0],[0,128,0]]

# %%
png_file_count = sum(1 for filename in os.listdir(data_root+mask_dir) if filename.endswith('.png'))

print(png_file_count)
# Out:
# 12233

# %%
# 다운받은 데이터셋 확인
img = mmcv.imread(f'{data_root}/images/210_000.png')
plt.figure(figsize=(8, 6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset


@DATASETS.register_module()
class KiTS21Datasets(BaseSegDataset):
	# 클래스, 팔레트 정보에대한 딕셔너리 METAINFO 생성
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.png', seg_map_suffix='.png', **kwargs)

# %%
ls
# Out:
# '=2.0.0rc4.'                model_configs/
#  CITATION.cff               notebooks/
#  LICENSE                    requirements/
#  MANIFEST.in                requirements.txt
#  README_zh-CN.md            resources/
#  configs/                   segmenter_swin-t_mask_8xb1-160k_ade20k-512x512.py
#  dataset-index.yml          setup.cfg
#  datasets/                  setup.py*
#  demo/                      swin_tiny_patch4_window7_224_20220317-1cdeb081.pth
#  docker/                    test.py
#  docs/                      tests/
#  driver_installer.run       tools/
#  evaluation_mask_9-2.py     train.py*
#  mmseg/                     work_dirs/
#  mmsegmentation.egg-info/

# %%
from mmengine import Config
cfg = Config.fromfile('segmenter_swin-t_mask_8xb1-160k_ade20k-512x512.py')
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# ann_dir = 'labels'
# backbone_norm_cfg = dict(eps=1e-06, requires_grad=True, type='LN')
# checkpoint = './work_dirs/Swin-Seg/batch24lr0.01/epoch_300.pth'
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         127.5,
#         127.5,
#         127.5,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         256,
#         256,
#     ),
#     std=[
#         127.5,
#         127.5,
#         127.5,
#     ],
#     type='SegDataPreProcessor')
# data_root = '/home/modan9012/mmsegmentation/datasets/'
# dataset_type = 'KiTS21Datasets'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=True, interval=10, type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.01, monitor='loss', patience=10, type='EarlyStoppingHook'),
#     logger=dict(interval=1, log_metric_by_epoch=True, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_dir = 'images/'
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = None
# log_level = 'DEBUG'
# log_processor = dict(by_epoch=True)
# model = dict(
#     backbone=dict(
#         act_cfg=dict(type='GELU'),
#         attn_drop_rate=0.0,
#         depths=[
#             2,
#             2,
#             6,
#             2,
#         ],
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         embed_dims=96,
#         init_cfg=dict(
#             checkpoint='./work_dirs/Swin-Seg/batch24lr0.01/epoch_300.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         norm_cfg=dict(eps=1e-06, requires_grad=True, type='LN'),
#         num_heads=[
#             3,
#             6,
#             12,
#             24,
#         ],
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         patch_size=4,
#         pretrain_img_size=224,
#         qk_scale=None,
#         qkv_bias=True,
#         strides=(
#             4,
#             2,
#             2,
#             2,
#         ),
#         type='SwinTransformer',
#         use_abs_pos_embed=False,
#         window_size=7),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             127.5,
#             127.5,
#             127.5,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             127.5,
#             127.5,
#             127.5,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         channels=768,
#         dropout_ratio=0.0,
#         embed_dims=768,
#         in_channels=768,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         num_classes=3,
#         num_heads=12,
#         num_layers=2,
#         out_channels=3,
#         type='SegmenterMaskTransformerHead'),
#     test_cfg=dict(crop_size=(
#         256,
#         256,
#     ), mode='slide', stride=(
#         128,
#         128,
#     )),
#     type='EncoderDecoder')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=80,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_data_root = './datasets/test-small/'
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='./datasets/test-small/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     format_only=True,
#     iou_metrics=[
#         'mIoU',
#     ],
#     keep_results=True,
#     output_dir='./work_dirs/Swin-Seg/batch24lr0.01/format_results',
#     type='IoUMetric')
# test_img_dir = 'images'
# test_mask_dir = 'masks'
# train_cfg = dict(max_epochs=430, type='EpochBasedTrainLoop', val_interval=10)
# train_dataloader = dict(
#     batch_size=24,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images/', seg_map_path='labels'),
#         data_root='/home/modan9012/mmsegmentation/datasets/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     256,
#                     256,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(reduce_zero_label=False, type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             256,
#             256,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images/', seg_map_path='labels'),
#         data_root='/home/modan9012/mmsegmentation/datasets/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(reduce_zero_label=False, type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])

# %% [markdown]
# #### **Test config 설정**

# %%
cfg.norm_cfg = dict(type='LN', requires_grad=True)
cfg.crop_size = (256,256)
cfg.model.data_preprocessor.size = (256,256)
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.num_classes = 3
cfg.model.decode_head.out_channels= 3
cfg.model.decode_head.loss_decode=dict(type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)
cfg.model.decode_head.threshold = 0.3

cfg.optim_wrapper.optimizer.lr = 0.01




# test 파이프라인을 설정
cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(256, 256), keep_ratio=True),
    dict(type='PackSegInputs')
]

#test dataloader 설정
cfg.test_dataloader.dataset.type = cfg.dataset_type
cfg.test_dataloader.dataset.data_root = cfg.data_root
cfg.test_dataloader.dataset.data_prefix = dict(img_path=img_dir)
cfg.test_dataloader.dataset.pipeline = cfg.test_pipeline

#test_evaluator 설정
 

# 사전학습된 모델 checkpoint 불러오기
cfg.load_from = './work_dirs/Swin-Seg/batch24lr0.01/epoch_340.pth'

#로그 디렉토리 설정
cfg.work_dir = './work_dirs/Swin-Seg/batch24lr0.01/'


#결과 재현을 위한 시드 값을 설정
cfg['randomness'] = dict(seed=0)

#최종 설정(config)을 출력
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# ann_dir = 'labels'
# backbone_norm_cfg = dict(eps=1e-06, requires_grad=True, type='LN')
# checkpoint = './work_dirs/Swin-Seg/batch24lr0.01/epoch_300.pth'
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         127.5,
#         127.5,
#         127.5,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         256,
#         256,
#     ),
#     std=[
#         127.5,
#         127.5,
#         127.5,
#     ],
#     type='SegDataPreProcessor')
# data_root = './datasets/test-small/'
# dataset_type = 'KiTS21Datasets'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=True, interval=10, type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.01, monitor='loss', patience=10, type='EarlyStoppingHook'),
#     logger=dict(interval=1, log_metric_by_epoch=True, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_dir = 'images/'
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = './work_dirs/Swin-Seg/batch24lr0.01/epoch_340.pth'
# log_level = 'DEBUG'
# log_processor = dict(by_epoch=True)
# model = dict(
#     backbone=dict(
#         act_cfg=dict(type='GELU'),
#         attn_drop_rate=0.0,
#         depths=[
#             2,
#             2,
#             6,
#             2,
#         ],
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         embed_dims=96,
#         init_cfg=dict(
#             checkpoint='./work_dirs/Swin-Seg/batch24lr0.01/epoch_300.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         norm_cfg=dict(requires_grad=True, type='LN'),
#         num_heads=[
#             3,
#             6,
#             12,
#             24,
#         ],
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         patch_size=4,
#         pretrain_img_size=224,
#         qk_scale=None,
#         qkv_bias=True,
#         strides=(
#             4,
#             2,
#             2,
#             2,
#         ),
#         type='SwinTransformer',
#         use_abs_pos_embed=False,
#         window_size=7),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             127.5,
#             127.5,
#             127.5,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             127.5,
#             127.5,
#             127.5,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         channels=768,
#         dropout_ratio=0.0,
#         embed_dims=768,
#         in_channels=768,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='LN'),
#         num_classes=3,
#         num_heads=12,
#         num_layers=2,
#         out_channels=3,
#         threshold=0.3,
#         type='SegmenterMaskTransformerHead'),
#     test_cfg=dict(crop_size=(
#         256,
#         256,
#     ), mode='slide', stride=(
#         128,
#         128,
#     )),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='LN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=80,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_data_root = './datasets/test-small/'
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='images'),
#         data_root='./datasets/test-small/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     format_only=True,
#     iou_metrics=[
#         'mIoU',
#     ],
#     keep_results=True,
#     output_dir='./work_dirs/Swin-Seg/batch24lr0.01/format_results',
#     type='IoUMetric')
# test_img_dir = 'images'
# test_mask_dir = 'masks'
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_epochs=430, type='EpochBasedTrainLoop', val_interval=10)
# train_dataloader = dict(
#     batch_size=24,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images/', seg_map_path='labels'),
#         data_root='/home/modan9012/mmsegmentation/datasets/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     256,
#                     256,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(reduce_zero_label=False, type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             256,
#             256,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images/', seg_map_path='labels'),
#         data_root='/home/modan9012/mmsegmentation/datasets/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(reduce_zero_label=False, type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/Swin-Seg/batch24lr0.01/'

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)
# Out:
# 06/10 07:11:51 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.19 | packaged by conda-forge | (default, Mar 20 2024, 12:47:35) [GCC 12.3.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Debian 10.2.1-6) 10.2.1 20210110
#     PyTorch: 1.12.0+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.9  (built against CUDA 11.8)
#     - Built with CuDNN 8.3.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.0+cu116
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/10 07:11:52 - mmengine - INFO - Config:
# ann_dir = 'labels'
# backbone_norm_cfg = dict(eps=1e-06, requires_grad=True, type='LN')
# checkpoint = './work_dirs/Swin-Seg/batch24lr0.01/epoch_300.pth'
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         127.5,
#         127.5,
#         127.5,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         256,
#         256,
#     ),
#     std=[
#         127.5,
#         127.5,
#         127.5,
#     ],
#     type='SegDataPreProcessor')
# data_root = './datasets/test-small/'
# dataset_type = 'KiTS21Datasets'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=True, interval=10, type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.01, monitor='loss', patience=10, type='EarlyStoppingHook'),
#     logger=dict(interval=1, log_metric_by_epoch=True, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_dir = 'images/'
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = './work_dirs/Swin-Seg/batch24lr0.01/epoch_340.pth'
# log_level = 'DEBUG'
# log_processor = dict(by_epoch=True)
# model = dict(
#     backbone=dict(
#         act_cfg=dict(type='GELU'),
#         attn_drop_rate=0.0,
#         depths=[
#             2,
#             2,
#             6,
#             2,
#         ],
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         embed_dims=96,
#         init_cfg=dict(
#             checkpoint='./work_dirs/Swin-Seg/batch24lr0.01/epoch_300.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         norm_cfg=dict(requires_grad=True, type='LN'),
#         num_heads=[
#             3,
#             6,
#             12,
#             24,
#         ],
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         patch_size=4,
#         pretrain_img_size=224,
#         qk_scale=None,
#         qkv_bias=True,
#         strides=(
#             4,
#             2,
#             2,
#             2,
#         ),
#         type='SwinTransformer',
#         use_abs_pos_embed=False,
#         window_size=7),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             127.5,
#             127.5,
#             127.5,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             127.5,
#             127.5,
#             127.5,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         channels=768,
#         dropout_ratio=0.0,
#         embed_dims=768,
#         in_channels=768,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='LN'),
#         num_classes=3,
#         num_heads=12,
#         num_layers=2,
#         out_channels=3,
#         threshold=0.3,
#         type='SegmenterMaskTransformerHead'),
#     test_cfg=dict(crop_size=(
#         256,
#         256,
#     ), mode='slide', stride=(
#         128,
#         128,
#     )),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='LN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=80,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_data_root = './datasets/test-small/'
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='images'),
#         data_root='./datasets/test-small/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     format_only=True,
#     iou_metrics=[
#         'mIoU',
#     ],
#     keep_results=True,
#     output_dir='./work_dirs/Swin-Seg/batch24lr0.01/format_results',
#     type='IoUMetric')
# test_img_dir = 'images'
# test_mask_dir = 'masks'
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_epochs=430, type='EpochBasedTrainLoop', val_interval=10)
# train_dataloader = dict(
#     batch_size=24,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images/', seg_map_path='labels'),
#         data_root='/home/modan9012/mmsegmentation/datasets/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     256,
#                     256,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(reduce_zero_label=False, type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             256,
#             256,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images/', seg_map_path='labels'),
#         data_root='/home/modan9012/mmsegmentation/datasets/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(reduce_zero_label=False, type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         reduce_zero_label=False,
#         type='KiTS21Datasets'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(reduce_zero_label=False, type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/Swin-Seg/batch24lr0.01/'
#
# 06/10 07:11:52 - mmengine - DEBUG - Get class `SegLocalVisualizer` from "visualizer" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - An `SegLocalVisualizer` instance is built from registry, and its implementation can be found in mmseg.visualization.local_visualizer
# 06/10 07:11:52 - mmengine - DEBUG - Get class `EncoderDecoder` from "model" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `SegDataPreProcessor` from "model" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - An `SegDataPreProcessor` instance is built from registry, and its implementation can be found in mmseg.models.data_preprocessor
# 06/10 07:11:52 - mmengine - DEBUG - Get class `SwinTransformer` from "model" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `Conv2d` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `SwinTransformer` instance is built from registry, and its implementation can be found in mmseg.models.backbones.swin
# 06/10 07:11:52 - mmengine - DEBUG - Get class `SegmenterMaskTransformerHead` from "model" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `CrossEntropyLoss` from "model" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - An `CrossEntropyLoss` instance is built from registry, and its implementation can be found in mmseg.models.losses.cross_entropy_loss
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `Dropout` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `Dropout` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `Dropout` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `Dropout` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `GELU` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `GELU` instance is built from registry, and its implementation can be found in torch.nn.modules.activation
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DropPath` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DropPath` instance is built from registry, and its implementation can be found in mmcv.cnn.bricks.drop
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LayerNorm` from "model" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `SegmenterMaskTransformerHead` instance is built from registry, and its implementation can be found in mmseg.models.decode_heads.segmenter_mask_head
# 06/10 07:11:52 - mmengine - DEBUG - An `EncoderDecoder` instance is built from registry, and its implementation can be found in mmseg.models.segmentors.encoder_decoder
# 06/10 07:11:52 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/10 07:11:52 - mmengine - DEBUG - Get class `RuntimeInfoHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `RuntimeInfoHook` instance is built from registry, and its implementation can be found in mmengine.hooks.runtime_info_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `IterTimerHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `IterTimerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.iter_timer_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `DistSamplerSeedHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `DistSamplerSeedHook` instance is built from registry, and its implementation can be found in mmengine.hooks.sampler_seed_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `LoggerHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `LoggerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.logger_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `ParamSchedulerHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `ParamSchedulerHook` instance is built from registry, and its implementation can be found in mmengine.hooks.param_scheduler_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `CheckpointHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `CheckpointHook` instance is built from registry, and its implementation can be found in mmengine.hooks.checkpoint_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `SegVisualizationHook` from "hook" registry in "mmseg"
# 06/10 07:11:52 - mmengine - DEBUG - An `SegVisualizationHook` instance is built from registry, and its implementation can be found in mmseg.engine.hooks.visualization_hook
# 06/10 07:11:52 - mmengine - DEBUG - Get class `EarlyStoppingHook` from "hook" registry in "mmengine"
# 06/10 07:11:52 - mmengine - DEBUG - An `EarlyStoppingHook` instance is built from registry, and its implementation can be found in mmengine.hooks.early_stopping_hook
# 06/10 07:11:52 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
# 모델 학습 진행
runner.test()
# Out:
# 06/10 07:11:55 - mmengine - DEBUG - Get class `TestLoop` from "loop" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - Get class `KiTS21Datasets` from "dataset" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - Modules of mmseg's transform registry have been automatically imported from mmseg.datasets.transforms
# 06/10 07:11:55 - mmengine - DEBUG - Get class `LoadImageFromFile` from "transform" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - An `LoadImageFromFile` instance is built from registry, and its implementation can be found in mmcv.transforms.loading
# 06/10 07:11:55 - mmengine - DEBUG - Get class `Resize` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `Resize` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.transforms
# 06/10 07:11:55 - mmengine - DEBUG - Get class `PackSegInputs` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `PackSegInputs` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.formatting
# 06/10 07:11:55 - mmengine - DEBUG - An `KiTS21Datasets` instance is built from registry, and its implementation can be found in __main__
# 06/10 07:11:55 - mmengine - DEBUG - The "data sampler" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 06/10 07:11:55 - mmengine - DEBUG - Get class `DefaultSampler` from "data sampler" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - An `DefaultSampler` instance is built from registry, and its implementation can be found in mmengine.dataset.sampler
# 06/10 07:11:55 - mmengine - DEBUG - Get class `pseudo_collate` from "function" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - Modules of mmseg's metric registry have been automatically imported from mmseg.evaluation
# 06/10 07:11:55 - mmengine - DEBUG - Get class `IoUMetric` from "metric" registry in "mmseg"
# 06/10 07:11:55 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 06/10 07:11:55 - mmengine - DEBUG - An `IoUMetric` instance is built from registry, and its implementation can be found in mmseg.evaluation.metrics.iou_metric
# 06/10 07:11:55 - mmengine - DEBUG - An `TestLoop` instance is built from registry, and its implementation can be found in mmengine.runner.loops
# 06/10 07:11:55 - mmengine - DEBUG - Get class `EpochBasedTrainLoop` from "loop" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - Get class `KiTS21Datasets` from "dataset" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - Get class `LoadImageFromFile` from "transform" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - An `LoadImageFromFile` instance is built from registry, and its implementation can be found in mmcv.transforms.loading
# 06/10 07:11:55 - mmengine - DEBUG - Get class `LoadAnnotations` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `LoadAnnotations` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.loading
# 06/10 07:11:55 - mmengine - DEBUG - Get class `RandomResize` from "transform" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - Get class `Resize` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `Resize` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.transforms
# 06/10 07:11:55 - mmengine - DEBUG - An `RandomResize` instance is built from registry, and its implementation can be found in mmcv.transforms.processing
# 06/10 07:11:55 - mmengine - DEBUG - Get class `RandomCrop` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `RandomCrop` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.transforms
# 06/10 07:11:55 - mmengine - DEBUG - Get class `RandomFlip` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `RandomFlip` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.transforms
# 06/10 07:11:55 - mmengine - DEBUG - Get class `PhotoMetricDistortion` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `PhotoMetricDistortion` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.transforms
# 06/10 07:11:55 - mmengine - DEBUG - Get class `PackSegInputs` from "transform" registry in "mmseg"
# 06/10 07:11:55 - mmengine - DEBUG - An `PackSegInputs` instance is built from registry, and its implementation can be found in mmseg.datasets.transforms.formatting
# 06/10 07:11:55 - mmengine - DEBUG - An `KiTS21Datasets` instance is built from registry, and its implementation can be found in __main__
# 06/10 07:11:55 - mmengine - DEBUG - Get class `DefaultSampler` from "data sampler" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - An `DefaultSampler` instance is built from registry, and its implementation can be found in mmengine.dataset.sampler
# 06/10 07:11:55 - mmengine - DEBUG - Get class `pseudo_collate` from "function" registry in "mmengine"
# 06/10 07:11:55 - mmengine - DEBUG - An `EpochBasedTrainLoop` instance is built from registry, and its implementation can be found in mmengine.runner.loops
# Loads checkpoint by local backend from path: ./work_dirs/Swin-Seg/batch24lr0.01/epoch_340.pth
# /home/modan9012/mmsegmentation/mmseg/datasets/transforms/loading.py:84: UserWarning: `reduce_zero_label` will be deprecated, if you would like to ignore the zero label, please set `reduce_zero_label=True` when dataset initialized
#   warnings.warn('`reduce_zero_label` will be deprecated, '
# 06/10 07:11:56 - mmengine - INFO - Load checkpoint from ./work_dirs/Swin-Seg/batch24lr0.01/epoch_340.pth
# 06/10 07:11:56 - mmengine - INFO - Epoch(test) [    1/12233]    eta: 1:04:18  time: 0.3155  data_time: 0.1138  memory: 366
# 06/10 07:11:56 - mmengine - INFO - Epoch(test) [    2/12233]    eta: 0:44:43  time: 0.2194  data_time: 0.1085  memory: 366
# 06/10 07:11:57 - mmengine - INFO - Epoch(test) [    3/12233]    eta: 0:47:22  time: 0.2324  data_time: 0.1513  memory: 366
# 06/10 07:11:57 - mmengine - INFO - Epoch(test) [    4/12233]    eta: 0:45:43  time: 0.2244  data_time: 0.1575  memory: 366
# 06/10 07:11:57 - mmengine - INFO - Epoch(test) [    5/12233]    eta: 0:42:07  time: 0.2067  data_time: 0.1485  memory: 366
# 06/10 07:26:48 - mmengine - INFO - Epoch(test) [ 5563/12233]    eta: 0:17:49  time: 0.1611  data_time: 0.1409  memory: 366
# 06/10 07:26:48 - mmengine - INFO - Epoch(test) [ 5564/12233]    eta: 0:17:49  time: 0.1512  data_time: 0.1311  memory: 366
# 06/10 07:26:49 - mmengine - INFO - Epoch(test) [ 5565/12233]    eta: 0:17:49  time: 0.1608  data_time: 0.1407  memory: 366
# 06/10 07:26:49 - mmengine - INFO - Epoch(test) [ 5566/12233]    eta: 0:17:49  time: 0.1608  data_time: 0.1407  memory: 366
# 06/10 07:26:49 - mmengine - INFO - Epoch(test) [ 5567/12233]    eta: 0:17:49  time: 0.1617  data_time: 0.1415  memory: 366
# 06/10 07:26:49 - mmengine - INFO - Epoch(test) [ 5568/12233]    eta: 0:17:48  time: 0.1531  data_time: 0.1326  memory: 366
# 06/10 07:26:49 - mmengine - INFO - Epoch(test) [ 5569/12233]    eta: 0:17:48  time: 0.1634  data_time: 0.1428  memory: 366
# 06/10 07:26:49 - mmengine - INFO - Epoch(test) [ 5570/12233]    eta: 0:17:48  time: 0.1536  data_time: 0.1330  memory: 366
# 06/10 07:26:50 - mmengine - INFO - Epoch(test) [ 5571/12233]    eta: 0:17:48  time: 0.1636  data_time: 0.1427  memory: 366
# 06/10 07:26:50 - mmengine - INFO - Epoch(test) [ 5572/12233]    eta: 0:17:48  time: 0.1635  data_time: 0.1426  memory: 366
# 06/10 07:26:50 - mmengine - INFO - Epoch(test) [ 5573/12233]    eta: 0:17:48  time: 0.1542  data_time: 0.1333  memory: 366
# 06/10 07:26:50 - mmengine - INFO - Epoch(test) [ 5574/12233]    eta: 0:17:47  time: 0.1640  data_time: 0.1430  memory: 366
# 06/10 07:26:50 - mmengine - INFO - Epoch(test) [ 5575/12233]    eta: 0:17:47  time: 0.1641  data_time: 0.1430  memory: 366
# 06/10 07:26:50 - mmengine - INFO - Epoch(test) [ 5576/12233]    eta: 0:17:47  time: 0.1645  data_time: 0.1435  memory: 366
# 06/10 07:26:51 - mmengine - INFO - Epoch(test) [ 5577/12233]    eta: 0:17:47  time: 0.1540  data_time: 0.1332  memory: 366
# 06/10 07:26:51 - mmengine - INFO - Epoch(test) [ 5578/12233]    eta: 0:17:47  time: 0.1626  data_time: 0.1420  memory: 366
# 06/10 07:26:51 - mmengine - INFO - Epoch(test) [ 5579/12233]    eta: 0:17:47  time: 0.1526  data_time: 0.1321  memory: 366

# %%
# !python ./evaluation_mask_9-2.py

# %%
cd ..
# Out:
# /home/modan9012

# %%
import shutil

# 압축할 폴더 경로
directory = '/home/modan9012/mmsegmentation/work_dirs/KiTS21_lr0.001_epoch300_batch16/'

# 압축 파일의 경로 및 이름 (확장자 제외)
output_filename = '/home/modan9012/KiTS21_lr0.001_epoch300_batch16/'

# 폴더를 ZIP 파일로 압축
shutil.make_archive(output_filename, 'zip', directory)

print(f'{output_filename}.zip 파일이 생성되었습니다.')
# Out:
# /home/modan9012/KiTS21_lr0.001_epoch300_batch16/.zip 파일이 생성되었습니다.
